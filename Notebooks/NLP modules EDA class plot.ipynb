# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from class_plot import plot_h # plot_h(train, test, 'class', hor = 13, ver = 6, per_dist=1.2, hor_dist=2000 )

# %%
df = pd.read_csv('Consumer_Complaints.csv')

# %%
plot_h(train, test, 'Product', hor=17, ver=12, per_dist=1.12, hor_dist = 5500)
