# %% [markdown]
# ### Sentence Lengths and Plot of the Sentence Lengths

# %%
import numpy as np
import pandas as pd

# %%
from class_ratio import ratio_ # ratio_(train, 'class')
from class_plot import plot_v # plot_v(train, test, 'class', hor = 13, ver = 6)
from class_plot import plot_h # plot_h(train, test, 'class', hor = 13, ver = 6)

# %%
from sents_plot import len_plot # len_plot(df, sents, **kwargs)
from sents_stats import sents_len # df, x, y = sents_len(df, sents)

# %% [markdown]
# ### ......

# %% [markdown]
# #### Module sents_len

# %%
df_len, x, y = sents_len(train, 'Sentence')

# %%
df_len.head(10)
# Out:
#         class                                           Sentence  len
# 39097       1  Haunting memories have managed to reappear  qu...   30
# 59725       1  LIVESTRONG band decision provoked furor Ten Vi...   30
# 101615      2  No playin #39; around, toys called unsafe As l...   42
# 88685       1  This week's schedule Durfee over Acton-Boxboro...   18
# 57661       0  Cheney: Kerry's View of Terrorism 'Naive' (AP)...   43
# 65838       0  Russia Urged to Combat Hazing in Army (AP) AP ...   47
# 48397       3  Space Station Oxygen Supply Fails The main oxy...   39
# 89873       0  Five die in stampede for train FOUR women and ...   43
# 61713       2  Yukos to cut output at Yugansk unit, plant may...   56
# 89047       2  Spitzer Plans to Sue Insurer New York Attorney...   40

# %% [markdown]
# ### .......

# %% [markdown]
# #### Module len_plot

# %%
len_plot(train, 'Sentence', hor = 24, ver=15)
